# %%
from byte_pair_encoding import BytePairEncoding

doc = "low low low low low lower lower newest newest newest newest newest newest widest widest widest"
bpe = BytePairEncoding(doc)

# %%
bpe.word_freq

# %%
bpe.word_chars

# %%
bpe.char_pairs

# %%
bpe.score_all_pair()

# %%
bpe.all_pair_scores
# Out:
# {('l', 'o'): 7,
#  ('o', 'w'): 7,
#  ('w', '_'): 5,
#  ('w', 'e'): 8,
#  ('e', 'r'): 2,
#  ('r', '_'): 2,
#  ('n', 'e'): 6,
#  ('e', 'w'): 6,
#  ('e', 's'): 9,
#  ('s', 't'): 9,
#  ('t', '_'): 9,
#  ('w', 'i'): 3,
#  ('i', 'd'): 3,
#  ('d', 'e'): 3}

# %%
bpe.build_score_heap()
[node.score for node in bpe.score_heap.max_heap]
# Out:
# [9, 9, 6, 8, 9, 3, 5, 6, 7, 2, 7, 2, 3, 3]

# %%
bpe.score_heap.extract().score
# Out:
# 8
